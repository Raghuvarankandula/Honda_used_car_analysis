# %%
## import all libraries

import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %%
## reading file and creating Data frame
df=pd.read_csv("honda_car_selling.csv")
df
# Out:
#      Year   kms Driven Fuel Type  Suspension        Price  \
# 0    2019   19006 kms    Petrol    Automatic    9.29 Lakh
# 1    2021   11936 kms    Petrol    Automatic   13.95 Lakh
# 2    2018   29635 kms    Petrol    Automatic    9.95 Lakh
# 3    2020   16163 kms    Petrol    Automatic   13.26 Lakh
# 4    2015  105114 kms    Petrol       Manual    5.68 Lakh
# ..    ...          ...       ...         ...          ...
# 994  2007   90000 kms    Petrol       Manual    1.22 Lakh
# 995  2016   31500 kms    Petrol       Manual    4.25 Lakh
# 996  2017   39735 kms    Petrol       Manual    5.10 Lakh
# 997  2017   36000 kms    Petrol       Manual    6.10 Lakh
# 998  2015   35341 kms    Diesel       Manual       3 Lakh
#
#                     Car Model
# 0            Honda City V CVT
# 1           Honda City ZX CVT
# 2    Honda City i-VTEC CVT ZX
# 3           Honda City ZX CVT
# 4         Honda City i VTEC V
# ..                        ...
# 994      Honda Civic 1.8 V MT
# 995      Honda Amaze S i-VTEC
# 996      Honda Amaze S Petrol
# 997       Honda City i VTEC S
# 998     Honda Amaze S i-Dtech
#
# [999 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        999 non-null    int64
#  1   kms Driven  999 non-null    object
#  2   Fuel Type   999 non-null    object
#  3   Suspension  999 non-null    object
#  4   Price       999 non-null    object
#  5   Car Model   999 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
## removing char part from kms driven column and convert it as int type

df['kms Driven']=df['kms Driven'].str.replace('kms','').astype(int)

# %%
df
# Out:
#      Year  kms Driven Fuel Type  Suspension        Price  \
# 0    2019       19006   Petrol    Automatic    9.29 Lakh
# 1    2021       11936   Petrol    Automatic   13.95 Lakh
# 2    2018       29635   Petrol    Automatic    9.95 Lakh
# 3    2020       16163   Petrol    Automatic   13.26 Lakh
# 4    2015      105114   Petrol       Manual    5.68 Lakh
# ..    ...         ...       ...         ...          ...
# 994  2007       90000   Petrol       Manual    1.22 Lakh
# 995  2016       31500   Petrol       Manual    4.25 Lakh
# 996  2017       39735   Petrol       Manual    5.10 Lakh
# 997  2017       36000   Petrol       Manual    6.10 Lakh
# 998  2015       35341   Diesel       Manual       3 Lakh
#
#                     Car Model
# 0            Honda City V CVT
# 1           Honda City ZX CVT
# 2    Honda City i-VTEC CVT ZX
# 3           Honda City ZX CVT
# 4         Honda City i VTEC V
# ..                        ...
# 994      Honda Civic 1.8 V MT
# 995      Honda Amaze S i-VTEC
# 996      Honda Amaze S Petrol
# 997       Honda City i VTEC S
# 998     Honda Amaze S i-Dtech
#
# [999 rows x 6 columns]

# %%
## finding the no of duplicated rows of the df
df.duplicated().value_counts()
# Out:
# False    974
# True      25
# dtype: int64

# %%
df.loc[df.duplicated(keep=False)]
# Out:
#      Year  kms Driven Fuel Type  Suspension        Price  \
# 221  2018       43326   Petrol       Manual    4.85 Lakh
# 223  2018       43326   Petrol       Manual    4.85 Lakh
# 307  2017       51000   Petrol    Automatic    8.99 Lakh
# 326  2012       48000   Petrol       Manual    2.75 Lakh
# 419  2020       60714   Petrol       Manual    6.90 Lakh
# 515  2017       51000   Petrol    Automatic    8.99 Lakh
# 734  2021       38352   Petrol       Manual    7.85 Lakh
# 735  2021       38352   Petrol       Manual    7.85 Lakh
# 739  2020       60714   Petrol       Manual    6.90 Lakh
# 786  2012       48000   Petrol       Manual    2.75 Lakh
# 812  2008       80000   Petrol       Manual       2 Lakh
# 960  2016       28000   Petrol       Manual    4.70 Lakh
# 961  2017       30000   Petrol       Manual    4.50 Lakh
# 962  2008       80000   Petrol       Manual       2 Lakh
# 963  2016       35000   Diesel       Manual    6.20 Lakh
# 964  2008      110000   Petrol       Manual    1.25 Lakh
# 965  2015       37326   Petrol       Manual       5 Lakh
# 966  2018       60000   Diesel       Manual       9 Lakh
# 967  2007      110000   Petrol       Manual    4.50 Lakh
# 968  2016       50000   Petrol    Automatic    7.80 Lakh
# 969  2006      110000   Petrol       Manual    1.80 Lakh
# 970  2017       16665   Petrol    Automatic   11.50 Lakh
# 971  2013      110000   Diesel       Manual    3.35 Lakh
# 972  2019       47297   Petrol    Automatic      15 Lakh
# 973  2006      186719   Petrol       Manual       90,000
# 974  2007       90000   Petrol       Manual    1.22 Lakh
# 975  2016       31500   Petrol       Manual    4.25 Lakh
# 976  2017       39735   Petrol       Manual    5.10 Lakh
# 977  2017       36000   Petrol       Manual    6.10 Lakh
# 978  2015       35341   Diesel       Manual       3 Lakh
# 980  2016       28000   Petrol       Manual    4.70 Lakh
# 981  2017       30000   Petrol       Manual    4.50 Lakh
# 982  2008       80000   Petrol       Manual       2 Lakh
# 983  2016       35000   Diesel       Manual    6.20 Lakh
# 984  2008      110000   Petrol       Manual    1.25 Lakh
# 985  2015       37326   Petrol       Manual       5 Lakh
# 986  2018       60000   Diesel       Manual       9 Lakh
# 987  2007      110000   Petrol       Manual    4.50 Lakh
# 988  2016       50000   Petrol    Automatic    7.80 Lakh
# 989  2006      110000   Petrol       Manual    1.80 Lakh
# 990  2017       16665   Petrol    Automatic   11.50 Lakh
# 991  2013      110000   Diesel       Manual    3.35 Lakh
# 992  2019       47297   Petrol    Automatic      15 Lakh
# 993  2006      186719   Petrol       Manual       90,000
# 994  2007       90000   Petrol       Manual    1.22 Lakh
# 995  2016       31500   Petrol       Manual    4.25 Lakh
# 996  2017       39735   Petrol       Manual    5.10 Lakh
# 997  2017       36000   Petrol       Manual    6.10 Lakh
# 998  2015       35341   Diesel       Manual       3 Lakh
#
#                     Car Model
# 221      Honda Amaze E i-VTEC
# 223      Honda Amaze E i-VTEC
# 307  Honda City i-VTEC CVT ZX
# 326           Honda Brio S MT
# 419      Honda Amaze S Petrol
# 515  Honda City i-VTEC CVT ZX
# 734     Honda Amaze VX Petrol
# 735     Honda Amaze VX Petrol
# 739      Honda Amaze S Petrol
# 786           Honda Brio S MT
# 812      Honda Civic 1.8 V MT
# 960      Honda Brio 1.2 VX MT
# 961      Honda Amaze S i-VTEC
# 962      Honda Civic 1.8 V MT
# 963  Honda Jazz 1.5 VX i DTEC
# 964      Honda Civic 1.8 V MT
# 965   Honda Jazz 1.2 S i VTEC
# 966       Honda City i-DTEC V
# 967         Honda CR-V RVi MT
# 968  Honda City i VTEC CVT SV
# 969            Honda City GXi
# 970  Honda City i-VTEC CVT VX
# 971    Honda Amaze EX i-Dtech
# 972            Honda Civic ZX
# 973            Honda City GXi
# 974      Honda Civic 1.8 V MT
# 975      Honda Amaze S i-VTEC
# 976      Honda Amaze S Petrol
# 977       Honda City i VTEC S
# 978     Honda Amaze S i-Dtech
# 980      Honda Brio 1.2 VX MT
# 981      Honda Amaze S i-VTEC
# 982      Honda Civic 1.8 V MT
# 983  Honda Jazz 1.5 VX i DTEC
# 984      Honda Civic 1.8 V MT
# 985   Honda Jazz 1.2 S i VTEC
# 986       Honda City i-DTEC V
# 987         Honda CR-V RVi MT
# 988  Honda City i VTEC CVT SV
# 989            Honda City GXi
# 990  Honda City i-VTEC CVT VX
# 991    Honda Amaze EX i-Dtech
# 992            Honda Civic ZX
# 993            Honda City GXi
# 994      Honda Civic 1.8 V MT
# 995      Honda Amaze S i-VTEC
# 996      Honda Amaze S Petrol
# 997       Honda City i VTEC S
# 998     Honda Amaze S i-Dtech

# %%
## removing the dupliactes keeping the first occurance as original
df=df.drop_duplicates(keep='first')

# %%
df
# Out:
#      Year  kms Driven Fuel Type  Suspension        Price  \
# 0    2019       19006   Petrol    Automatic    9.29 Lakh
# 1    2021       11936   Petrol    Automatic   13.95 Lakh
# 2    2018       29635   Petrol    Automatic    9.95 Lakh
# 3    2020       16163   Petrol    Automatic   13.26 Lakh
# 4    2015      105114   Petrol       Manual    5.68 Lakh
# ..    ...         ...       ...         ...          ...
# 975  2016       31500   Petrol       Manual    4.25 Lakh
# 976  2017       39735   Petrol       Manual    5.10 Lakh
# 977  2017       36000   Petrol       Manual    6.10 Lakh
# 978  2015       35341   Diesel       Manual       3 Lakh
# 979  2017        8602   Petrol       Manual    7.25 Lakh
#
#                     Car Model
# 0            Honda City V CVT
# 1           Honda City ZX CVT
# 2    Honda City i-VTEC CVT ZX
# 3           Honda City ZX CVT
# 4         Honda City i VTEC V
# ..                        ...
# 975      Honda Amaze S i-VTEC
# 976      Honda Amaze S Petrol
# 977       Honda City i VTEC S
# 978     Honda Amaze S i-Dtech
# 979       Honda City V MT AVN
#
# [974 rows x 6 columns]

# %%
## checking if any null value is there in any cloumn

df.isna().sum()
# Out:
# Year          0
# kms Driven    0
# Fuel Type     0
# Suspension    0
# Price         0
# Car Model     0
# dtype: int64

# %%
## to see top 10 most common car models with year come for the sale
df_top_car_model=df.groupby(['Year', 'Car Model']).size().nlargest(10).to_frame().reset_index()
df_top_car_model.columns=['Year','Car Model', 'Count']
df_top_car_model
# Out:
#    Year              Car Model  Count
# 0  2009    Honda City 1.5 S MT     21
# 1  2010    Honda City 1.5 S MT     19
# 2  2014  Honda Amaze S i-Dtech     16
# 3  2013        Honda Brio S MT     13
# 4  2014   Honda City i DTEC SV     13
# 5  2017    Honda City i VTEC V     13
# 6  2015  Honda Amaze S i-Vtech     11
# 7  2015    Honda City i VTEC V     11
# 8  2008         Honda City GXi     10
# 9  2014   Honda City i DTEC VX     10

# %%
## visualization

fig=px.bar(df_top_car_model,x='Year',y='Count',hover_name='Car Model',color='Car Model')
fig.show()
# Out:
# <div>                            <div id="6c23b53b-23fa-4835-85de-6bcc4e5343a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c23b53b-23fa-4835-85de-6bcc4e5343a7")) {                    Plotly.newPlot(                        "6c23b53b-23fa-4835-85de-6bcc4e5343a7",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda City 1.5 S MT<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda City 1.5 S MT","Honda City 1.5 S MT"],"legendgroup":"Honda City 1.5 S MT","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Honda City 1.5 S MT","offsetgroup":"Honda City 1.5 S MT","orientation":"v","showlegend":true,"textposition":"auto","x":[2009,2010],"xaxis":"x","y":[21,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S i-Dtech<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S i-Dtech"],"legendgroup":"Honda Amaze S i-Dtech","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Honda Amaze S i-Dtech","offsetgroup":"Honda Amaze S i-Dtech","orientation":"v","showlegend":true,"textposition":"auto","x":[2014],"xaxis":"x","y":[16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Brio S MT<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Brio S MT"],"legendgroup":"Honda Brio S MT","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Honda Brio S MT","offsetgroup":"Honda Brio S MT","orientation":"v","showlegend":true,"textposition":"auto","x":[2013],"xaxis":"x","y":[13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda City i DTEC SV<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda City i DTEC SV"],"legendgroup":"Honda City i DTEC SV","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Honda City i DTEC SV","offsetgroup":"Honda City i DTEC SV","orientation":"v","showlegend":true,"textposition":"auto","x":[2014],"xaxis":"x","y":[13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda City i VTEC V<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda City i VTEC V","Honda City i VTEC V"],"legendgroup":"Honda City i VTEC V","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Honda City i VTEC V","offsetgroup":"Honda City i VTEC V","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2015],"xaxis":"x","y":[13,11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S i-Vtech<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S i-Vtech"],"legendgroup":"Honda Amaze S i-Vtech","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Honda Amaze S i-Vtech","offsetgroup":"Honda Amaze S i-Vtech","orientation":"v","showlegend":true,"textposition":"auto","x":[2015],"xaxis":"x","y":[11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda City GXi<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda City GXi"],"legendgroup":"Honda City GXi","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Honda City GXi","offsetgroup":"Honda City GXi","orientation":"v","showlegend":true,"textposition":"auto","x":[2008],"xaxis":"x","y":[10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda City i DTEC VX<br>Year=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda City i DTEC VX"],"legendgroup":"Honda City i DTEC VX","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Honda City i DTEC VX"," ...

# %%
#To see how many number of each car brands with three different types of fuel
df_fuel=df.groupby(['Fuel Type','Car Model']).size().to_frame().reset_index()
df_fuel.columns=['Fuel Type','Car Model','Count']
df_fuel
# Out:
#     Fuel Type                  Car Model  Count
# 0        CNG   Honda Amaze S Plus i-VTEC      1
# 1     Diesel   Honda Amaze E Option i-DT      2
# 2     Diesel        Honda Amaze E i-DTEC      1
# 3     Diesel       Honda Amaze E i-Dtech      3
# 4     Diesel      Honda Amaze EX i-Dtech      4
# ..        ...                        ...    ...
# 179   Petrol   Honda WR-V Edge Edition i      2
# 180   Petrol               Honda WR-V SV      1
# 181   Petrol               Honda WR-V VX      2
# 182   Petrol         Honda WR-V i-VTEC S      4
# 183   Petrol        Honda WR-V i-VTEC VX     14
#
# [184 rows x 3 columns]

# %%
#Graphical visual
fig=px.bar(df_fuel,x='Fuel Type',y='Count',                  
           hover_name='Car Model',
          color='Car Model',
          range_y=[0,1000])
          
fig.show()
# Out:
# <div>                            <div id="20170f8f-2709-4bf5-85d2-6c8e0365bef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20170f8f-2709-4bf5-85d2-6c8e0365bef5")) {                    Plotly.newPlot(                        "20170f8f-2709-4bf5-85d2-6c8e0365bef5",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S Plus i-VTEC<br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S Plus i-VTEC"],"legendgroup":"Honda Amaze S Plus i-VTEC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Honda Amaze S Plus i-VTEC","offsetgroup":"Honda Amaze S Plus i-VTEC","orientation":"v","showlegend":true,"textposition":"auto","x":[" CNG "],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze E Option i-DT<br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze E Option i-DT"],"legendgroup":"Honda Amaze E Option i-DT","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Honda Amaze E Option i-DT","offsetgroup":"Honda Amaze E Option i-DT","orientation":"v","showlegend":true,"textposition":"auto","x":[" Diesel "],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze E i-DTEC<br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze E i-DTEC"],"legendgroup":"Honda Amaze E i-DTEC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Honda Amaze E i-DTEC","offsetgroup":"Honda Amaze E i-DTEC","orientation":"v","showlegend":true,"textposition":"auto","x":[" Diesel "],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze E i-Dtech<br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze E i-Dtech"],"legendgroup":"Honda Amaze E i-Dtech","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Honda Amaze E i-Dtech","offsetgroup":"Honda Amaze E i-Dtech","orientation":"v","showlegend":true,"textposition":"auto","x":[" Diesel "],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze EX i-Dtech<br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze EX i-Dtech"],"legendgroup":"Honda Amaze EX i-Dtech","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Honda Amaze EX i-Dtech","offsetgroup":"Honda Amaze EX i-Dtech","orientation":"v","showlegend":true,"textposition":"auto","x":[" Diesel "],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze Exclusive Die<br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze Exclusive Die"],"legendgroup":"Honda Amaze Exclusive Die","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Honda Amaze Exclusive Die","offsetgroup":"Honda Amaze Exclusive Die","orientation":"v","showlegend":true,"textposition":"auto","x":[" Diesel "],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S CVT Diesel <br>Fuel Type=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S CVT Diesel "],"legendgroup":"Honda Amaze S CVT Diesel ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Honda Amaze S CVT Diesel ","offsetgroup":"Honda Amaze S CVT Diesel ","orientation":"v","showlegend":true,"textposition":"auto","x":[" Diesel "],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S Diesel<br>Fuel Type=%{x}<br>Co ...

# %%
df
# Out:
#      Year  kms Driven Fuel Type  Suspension        Price  \
# 0    2019       19006   Petrol    Automatic    9.29 Lakh
# 1    2021       11936   Petrol    Automatic   13.95 Lakh
# 2    2018       29635   Petrol    Automatic    9.95 Lakh
# 3    2020       16163   Petrol    Automatic   13.26 Lakh
# 4    2015      105114   Petrol       Manual    5.68 Lakh
# ..    ...         ...       ...         ...          ...
# 975  2016       31500   Petrol       Manual    4.25 Lakh
# 976  2017       39735   Petrol       Manual    5.10 Lakh
# 977  2017       36000   Petrol       Manual    6.10 Lakh
# 978  2015       35341   Diesel       Manual       3 Lakh
# 979  2017        8602   Petrol       Manual    7.25 Lakh
#
#                     Car Model
# 0            Honda City V CVT
# 1           Honda City ZX CVT
# 2    Honda City i-VTEC CVT ZX
# 3           Honda City ZX CVT
# 4         Honda City i VTEC V
# ..                        ...
# 975      Honda Amaze S i-VTEC
# 976      Honda Amaze S Petrol
# 977       Honda City i VTEC S
# 978     Honda Amaze S i-Dtech
# 979       Honda City V MT AVN
#
# [974 rows x 6 columns]

# %%
#To see the Car models under two different types of Suspension with fule type as Petrol
df_petrol = df[df['Fuel Type'] == ' Petrol ']
df_petrol_sus =df_petrol.groupby(['Suspension','Car Model']).size().to_frame().reset_index()
df_petrol_sus.columns=['Suspension','Car Model','Count']
df_petrol_sus
# Out:
#      Suspension                  Car Model  Count
# 0     Automatic        Honda Accord 2.4 AT      4
# 1     Automatic  Honda Accord 2.4 Elegance      1
# 2     Automatic    Honda Accord VTi-L (AT)      1
# 3     Automatic  Honda Amaze Exclusive Edi      2
# 4     Automatic   Honda Amaze S AT i-Vtech      3
# ..          ...                        ...    ...
# 128      Manual  Honda WR-V Edge Edition i      2
# 129      Manual              Honda WR-V SV      1
# 130      Manual              Honda WR-V VX      2
# 131      Manual        Honda WR-V i-VTEC S      4
# 132      Manual       Honda WR-V i-VTEC VX     14
#
# [133 rows x 3 columns]

# %%
#visualization tells that under each suspension what types of car models and how many number of cars with each model
fig=px.bar(df_petrol_sus,x='Suspension',y='Count',hover_name='Car Model',color='Car Model')
fig.show()
# Out:
# <div>                            <div id="5ce63924-5e91-406a-8d01-f13e3bf85e92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ce63924-5e91-406a-8d01-f13e3bf85e92")) {                    Plotly.newPlot(                        "5ce63924-5e91-406a-8d01-f13e3bf85e92",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Accord 2.4 AT<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Accord 2.4 AT"],"legendgroup":"Honda Accord 2.4 AT","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Honda Accord 2.4 AT","offsetgroup":"Honda Accord 2.4 AT","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Accord 2.4 Elegance<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Accord 2.4 Elegance"],"legendgroup":"Honda Accord 2.4 Elegance","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Honda Accord 2.4 Elegance","offsetgroup":"Honda Accord 2.4 Elegance","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Accord VTi-L (AT)<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Accord VTi-L (AT)"],"legendgroup":"Honda Accord VTi-L (AT)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Honda Accord VTi-L (AT)","offsetgroup":"Honda Accord VTi-L (AT)","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze Exclusive Edi<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze Exclusive Edi"],"legendgroup":"Honda Amaze Exclusive Edi","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Honda Amaze Exclusive Edi","offsetgroup":"Honda Amaze Exclusive Edi","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S AT i-Vtech<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S AT i-Vtech"],"legendgroup":"Honda Amaze S AT i-Vtech","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Honda Amaze S AT i-Vtech","offsetgroup":"Honda Amaze S AT i-Vtech","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S CVT<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S CVT"],"legendgroup":"Honda Amaze S CVT","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Honda Amaze S CVT","offsetgroup":"Honda Amaze S CVT","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S CVT Petrol <br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S CVT Petrol "],"legendgroup":"Honda Amaze S CVT Petrol ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Honda Amaze S CVT Petrol ","offsetgroup":"Honda Amaze S CVT Petrol ","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S CVT i-VTEC<br>Suspension=%{x}<b ...

# %%
#Finding the top 10 vehicles with the most miles driven when using petrol and Manual suspension
df_petrol_4year=df_petrol.loc[df_petrol['Year'].isin([2023,2022,2021,2020])]
df_petrol_4year_s=df_petrol_4year[df_petrol_4year['Suspension']==' Manual']
df_petrol_4year_s_top10_km=df_petrol_4year_s.sort_values('kms Driven',ascending=False).head(10)
df_petrol_4year_s_top10_km # top10 cars ran for highest km from the year b/w 2020 to 2023 with suspension type as Manual
# Out:
#      Year  kms Driven Fuel Type Suspension        Price              Car Model
# 775  2021      103000   Petrol      Manual    9.75 Lakh        Honda City V MT
# 455  2020       64092   Petrol      Manual      10 Lakh        Honda City V MT
# 419  2020       60714   Petrol      Manual    6.90 Lakh   Honda Amaze S Petrol
# 734  2021       38352   Petrol      Manual    7.85 Lakh  Honda Amaze VX Petrol
# 797  2020       35000   Petrol      Manual   12.95 Lakh       Honda City ZX MT
# 363  2020       35000   Petrol      Manual    7.99 Lakh   Honda City i-VTEC VX
# 758  2020       32093   Petrol      Manual    5.60 Lakh   Honda Amaze S Petrol
# 21   2020       30405   Petrol      Manual    6.50 Lakh   Honda Amaze S Petrol
# 933  2021       30000   Petrol      Manual    9.50 Lakh          Honda WR-V VX
# 241  2022       27690   Petrol      Manual   10.50 Lakh        Honda City V MT

# %%
#Finding the top 10 vehicles with the most miles driven when using petrol and automatic suspension
df_petrol_4year_s_a=df_petrol_4year[df_petrol_4year['Suspension']==' Automatic']
df_petrol_4year_s_a_top10_km=df_petrol_4year_s_a.sort_values('kms Driven',ascending=False).head(10)
df_petrol_4year_s_a_top10_km # top10 cars ran for highest km from the year b/w 2020 to 2023 with suspension type as Automatic
# Out:
#      Year  kms Driven Fuel Type  Suspension        Price  \
# 647  2020       52771   Petrol    Automatic    5.85 Lakh
# 405  2021       39011   Petrol    Automatic   13.45 Lakh
# 592  2021       39000   Petrol    Automatic   13.45 Lakh
# 913  2021       33500   Petrol    Automatic   12.50 Lakh
# 349  2020       30000   Petrol    Automatic   11.50 Lakh
# 938  2020       27500   Petrol    Automatic    8.75 Lakh
# 707  2022       20000   Petrol    Automatic    8.15 Lakh
# 344  2020       18731   Petrol    Automatic    7.90 Lakh
# 12   2020       17934   Petrol    Automatic   12.46 Lakh
# 10   2021       17152   Petrol    Automatic   11.98 Lakh
#
#                      Car Model
# 647  Honda Amaze S CVT Petrol
# 405   Honda City i-VTEC CVT VX
# 592   Honda City i-VTEC CVT VX
# 913          Honda City VX CVT
# 349   Honda City i-VTEC CVT VX
# 938  Honda Amaze Exclusive Edi
# 707          Honda Amaze S CVT
# 344  Honda Amaze VX CVT Petrol
# 12           Honda City ZX CVT
# 10           Honda City ZX CVT

# %%
## Diesel Cars

df_diesel = df[df['Fuel Type'] == ' Diesel ']
df_diesel_sus =df_diesel.groupby(['Suspension','Car Model']).size().to_frame().reset_index()
df_diesel_sus.columns=['Suspension','Car Model','Count']
df_diesel_sus.head(10)
# Out:
#    Suspension                  Car Model  Count
# 0   Automatic  Honda Amaze S CVT Diesel       1
# 1   Automatic  Honda Amaze V CVT Diesel       2
# 2   Automatic  Honda Amaze VX CVT Diesel      1
# 3   Automatic      Honda CR-V Diesel 2WD      1
# 4      Manual  Honda Amaze E Option i-DT      2
# 5      Manual       Honda Amaze E i-DTEC      1
# 6      Manual      Honda Amaze E i-Dtech      3
# 7      Manual     Honda Amaze EX i-Dtech      4
# 8      Manual  Honda Amaze Exclusive Die      1
# 9      Manual       Honda Amaze S Diesel      4

# %%
#The image explains which car models are under each suspension as well as how many of each type there are, all using deisel fuel.
fig=px.bar(df_diesel_sus,x='Suspension',y='Count',hover_name='Car Model',color='Car Model')
fig.show()
# Out:
# <div>                            <div id="6033ceb4-c22e-4878-835a-2593cd4998bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6033ceb4-c22e-4878-835a-2593cd4998bc")) {                    Plotly.newPlot(                        "6033ceb4-c22e-4878-835a-2593cd4998bc",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze S CVT Diesel <br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze S CVT Diesel "],"legendgroup":"Honda Amaze S CVT Diesel ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Honda Amaze S CVT Diesel ","offsetgroup":"Honda Amaze S CVT Diesel ","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze V CVT Diesel <br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze V CVT Diesel "],"legendgroup":"Honda Amaze V CVT Diesel ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Honda Amaze V CVT Diesel ","offsetgroup":"Honda Amaze V CVT Diesel ","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze VX CVT Diesel<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze VX CVT Diesel"],"legendgroup":"Honda Amaze VX CVT Diesel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Honda Amaze VX CVT Diesel","offsetgroup":"Honda Amaze VX CVT Diesel","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda CR-V Diesel 2WD<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda CR-V Diesel 2WD"],"legendgroup":"Honda CR-V Diesel 2WD","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Honda CR-V Diesel 2WD","offsetgroup":"Honda CR-V Diesel 2WD","orientation":"v","showlegend":true,"textposition":"auto","x":[" Automatic"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze E Option i-DT<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze E Option i-DT"],"legendgroup":"Honda Amaze E Option i-DT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Honda Amaze E Option i-DT","offsetgroup":"Honda Amaze E Option i-DT","orientation":"v","showlegend":true,"textposition":"auto","x":[" Manual"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze E i-DTEC<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze E i-DTEC"],"legendgroup":"Honda Amaze E i-DTEC","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Honda Amaze E i-DTEC","offsetgroup":"Honda Amaze E i-DTEC","orientation":"v","showlegend":true,"textposition":"auto","x":[" Manual"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze E i-Dtech<br>Suspension=%{x}<br>Count=%{y}<extra></extra>","hovertext":["Honda Amaze E i-Dtech"],"legendgroup":"Honda Amaze E i-Dtech","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Honda Amaze E i-Dtech","offsetgroup":"Honda Amaze E i-Dtech","orientation":"v","showlegend":true,"textposition":"auto","x":[" Manual"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=Honda Amaze EX i-Dtech<br>Suspensi ...

# %%
# filtering df with fuel type: Diesel, Suspension: Manual
df_desiel_4year=df_diesel.loc[df_diesel['Year'].isin([2023,2022,2021,2020])]
df_desiel_4year_s=df_desiel_4year[df_desiel_4year['Suspension']==' Manual']
df_desiel_4year_s_top_km=df_desiel_4year_s.sort_values('kms Driven',ascending=False)
df_desiel_4year_s_top_km
# Out:
#      Year  kms Driven Fuel Type Suspension       Price             Car Model
# 952  2021       70000   Diesel      Manual     10 Lakh  Honda WR-V VX Diesel
# 902  2021       60000   Diesel      Manual   4.22 Lakh  Honda Amaze S Diesel
# 228  2020       33174   Diesel      Manual   9.20 Lakh  Honda WR-V i-DTEC VX
# 435  2021       28183   Diesel      Manual   8.50 Lakh  Honda Amaze S Diesel

# %%
# filstering df with fuel type: Diesel, Suspension: Manual
df_desiel_4year=df_diesel.loc[df_diesel['Year'].isin([2023,2022,2021,2020])]
df_desiel_4year_s=df_desiel_4year[df_desiel_4year['Suspension']==' Automatic']
df_desiel_4year_s_top_km=df_desiel_4year_s.sort_values('kms Driven',ascending=False)
df_desiel_4year_s_top_km
# Out:
#      Year  kms Driven Fuel Type  Suspension        Price  \
# 917  2021       30000   Diesel    Automatic   11.50 Lakh
#
#                      Car Model
# 917  Honda Amaze VX CVT Diesel

# %%
## Price range analysis

#converting the price column with numerical values with lambda apply method
df['Price'] = df['Price'].apply(lambda x: float(x.replace('Lakh', ''))*100000 if x.endswith('Lakh') else float(x.replace(',', '')))
# Out:
# C:\Users\kandu\AppData\Local\Temp\ipykernel_20544\850604512.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Finding top10 costliest cars
df_top10_price=df.sort_values(by='Price',ascending=False).head(10)
df_top10_price
# Out:
#      Year  kms Driven Fuel Type  Suspension      Price  \
# 390  2019       50175   Diesel    Automatic  2650000.0
# 189  2019       33000   Petrol    Automatic  2490000.0
# 394  2019       10745   Petrol    Automatic  1754000.0
# 469  2019       18000   Petrol    Automatic  1725000.0
# 858  2019       79000   Diesel       Manual  1720000.0
# 222  2022        1661   Petrol       Manual  1600000.0
# 398  2022        5100   Petrol    Automatic  1590000.0
# 15   2022        5500   Petrol    Automatic  1590000.0
# 400  2022        3800   Petrol    Automatic  1590000.0
# 36   2021        5282   Petrol    Automatic  1526000.0
#
#                     Car Model
# 390     Honda CR-V Diesel 2WD
# 189        Honda CR-V 2.0 CVT
# 394            Honda Civic VX
# 469       Honda Civic VX BSIV
# 858     Honda Civic VX Diesel
# 222          Honda City VX MT
# 398  Honda City i-VTEC CVT ZX
# 15          Honda City ZX CVT
# 400  Honda City i-VTEC CVT ZX
# 36          Honda City ZX CVT

# %%
#Graphical representation
fig=px.bar(df_top10_price,x='Car Model',y='Price',hover_name='Year',color='Car Model',text_auto=True)
fig.update_layout(width=800,height=400)
fig.show()
# Out:
# <div>                            <div id="b8e3f5a6-9793-43ea-bddf-80183d1a38aa" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8e3f5a6-9793-43ea-bddf-80183d1a38aa")) {                    Plotly.newPlot(                        "b8e3f5a6-9793-43ea-bddf-80183d1a38aa",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2019.0],"legendgroup":"Honda CR-V Diesel 2WD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Honda CR-V Diesel 2WD","offsetgroup":"Honda CR-V Diesel 2WD","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda CR-V Diesel 2WD"],"xaxis":"x","y":[2650000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2019.0],"legendgroup":"Honda CR-V 2.0 CVT","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Honda CR-V 2.0 CVT","offsetgroup":"Honda CR-V 2.0 CVT","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda CR-V 2.0 CVT"],"xaxis":"x","y":[2490000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2019.0],"legendgroup":"Honda Civic VX","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Honda Civic VX","offsetgroup":"Honda Civic VX","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda Civic VX"],"xaxis":"x","y":[1754000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2019.0],"legendgroup":"Honda Civic VX BSIV","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Honda Civic VX BSIV","offsetgroup":"Honda Civic VX BSIV","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda Civic VX BSIV"],"xaxis":"x","y":[1725000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2019.0],"legendgroup":"Honda Civic VX Diesel","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Honda Civic VX Diesel","offsetgroup":"Honda Civic VX Diesel","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda Civic VX Diesel"],"xaxis":"x","y":[1720000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2022.0],"legendgroup":"Honda City VX MT","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Honda City VX MT","offsetgroup":"Honda City VX MT","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda City VX MT"],"xaxis":"x","y":[1600000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2022.0,2022.0],"legendgroup":"Honda City i-VTEC CVT ZX","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Honda City i-VTEC CVT ZX","offsetgroup":"Honda City i-VTEC CVT ZX","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda City i-VTEC CVT ZX","Honda City i-VTEC CVT ZX"],"xaxis":"x","y":[1590000.0,1590000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2022.0,2021.0],"legendgroup":"Honda City ZX CVT","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Honda City ZX CVT","offsetgroup":"Hond ...

# %%
#Finding top10 Cheapest cars
df_top10_price_Cheap=df.sort_values(by='Price',ascending=False).tail(10)
df_top10_price_Cheap
# Out:
#      Year  kms Driven Fuel Type Suspension     Price             Car Model
# 652  2008      114502   Petrol      Manual  100000.0  Honda Civic 1.8 V MT
# 764  2009       87163   Petrol      Manual  100000.0   Honda City 1.5 S MT
# 572  2008      223000   Petrol      Manual  100000.0        Honda City GXi
# 637  2009       78216   Petrol      Manual  100000.0      Honda Jazz Basic
# 939  2008       92000   Petrol      Manual   95000.0        Honda City GXi
# 973  2006      186719   Petrol      Manual   90000.0        Honda City GXi
# 802  2007      120000   Petrol      Manual   85000.0       Honda City VTEC
# 594  2008       39460   Petrol      Manual   80000.0  Honda Civic 1.8 S MT
# 828  2005      110000   Petrol      Manual   60000.0    Honda City 1.5 GXI
# 588  2003      149714   Petrol      Manual   45000.0    Honda City 1.5 GXI

# %%
#Graphical visualization
fig=px.bar(df_top10_price_Cheap,x='Car Model',y='Price',hover_name='Year',color='Car Model',text_auto=True)
fig.update_layout(width=800,height=400)
fig.show()
# Out:
# <div>                            <div id="65475bbe-4bd5-43ca-9c23-06baaff19ea9" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65475bbe-4bd5-43ca-9c23-06baaff19ea9")) {                    Plotly.newPlot(                        "65475bbe-4bd5-43ca-9c23-06baaff19ea9",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2008.0],"legendgroup":"Honda Civic 1.8 V MT","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Honda Civic 1.8 V MT","offsetgroup":"Honda Civic 1.8 V MT","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda Civic 1.8 V MT"],"xaxis":"x","y":[100000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2009.0],"legendgroup":"Honda City 1.5 S MT","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Honda City 1.5 S MT","offsetgroup":"Honda City 1.5 S MT","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda City 1.5 S MT"],"xaxis":"x","y":[100000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2008.0,2008.0,2006.0],"legendgroup":"Honda City GXi","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Honda City GXi","offsetgroup":"Honda City GXi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda City GXi","Honda City GXi","Honda City GXi"],"xaxis":"x","y":[100000.0,95000.0,90000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2009.0],"legendgroup":"Honda Jazz Basic","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Honda Jazz Basic","offsetgroup":"Honda Jazz Basic","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda Jazz Basic"],"xaxis":"x","y":[100000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2007.0],"legendgroup":"Honda City VTEC","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Honda City VTEC","offsetgroup":"Honda City VTEC","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda City VTEC"],"xaxis":"x","y":[85000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2008.0],"legendgroup":"Honda Civic 1.8 S MT","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Honda Civic 1.8 S MT","offsetgroup":"Honda Civic 1.8 S MT","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda Civic 1.8 S MT"],"xaxis":"x","y":[80000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Car Model=%{x}<br>Price=%{y}<extra></extra>","hovertext":[2005.0,2003.0],"legendgroup":"Honda City 1.5 GXI","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Honda City 1.5 GXI","offsetgroup":"Honda City 1.5 GXI","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Honda City 1.5 GXI","Honda City 1.5 GXI"],"xaxis":"x","y":[60000.0,45000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %%
#top10 costliest cars with fuel type as petrol and suspension type as Automatic
df_petrol_aut=df[(df['Fuel Type']==' Petrol ') & (df['Suspension']==' Automatic')]
df_petrol_aut_top10=df_petrol_aut.sort_values('Price',ascending=False).head(10)
df_petrol_aut_top10
# Out:
#      Year  kms Driven Fuel Type  Suspension      Price  \
# 189  2019       33000   Petrol    Automatic  2490000.0
# 394  2019       10745   Petrol    Automatic  1754000.0
# 469  2019       18000   Petrol    Automatic  1725000.0
# 15   2022        5500   Petrol    Automatic  1590000.0
# 398  2022        5100   Petrol    Automatic  1590000.0
# 400  2022        3800   Petrol    Automatic  1590000.0
# 36   2021        5282   Petrol    Automatic  1526000.0
# 972  2019       47297   Petrol    Automatic  1500000.0
# 897  2019       35000   Petrol    Automatic  1500000.0
# 694  2020        5512   Petrol    Automatic  1445000.0
#
#                     Car Model
# 189        Honda CR-V 2.0 CVT
# 394            Honda Civic VX
# 469       Honda Civic VX BSIV
# 15          Honda City ZX CVT
# 398  Honda City i-VTEC CVT ZX
# 400  Honda City i-VTEC CVT ZX
# 36          Honda City ZX CVT
# 972            Honda Civic ZX
# 897       Honda Civic VX BSIV
# 694         Honda City ZX CVT

# %%
fig=px.histogram(df_petrol_aut_top10,x='Car Model',nbins=10,color='Price',text_auto=True)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="b00df04b-74c6-4228-b35f-982f38d7cfe0" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b00df04b-74c6-4228-b35f-982f38d7cfe0")) {                    Plotly.newPlot(                        "b00df04b-74c6-4228-b35f-982f38d7cfe0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=2490000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2490000.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2490000.0","nbinsx":10,"offsetgroup":"2490000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda CR-V 2.0 CVT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1754000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1754000.0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1754000.0","nbinsx":10,"offsetgroup":"1754000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic VX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1725000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1725000.0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1725000.0","nbinsx":10,"offsetgroup":"1725000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic VX BSIV"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1590000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1590000.0","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1590000.0","nbinsx":10,"offsetgroup":"1590000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX CVT","Honda City i-VTEC CVT ZX","Honda City i-VTEC CVT ZX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1526000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1526000.0","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1526000.0","nbinsx":10,"offsetgroup":"1526000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX CVT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1500000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1500000.0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"1500000.0","nbinsx":10,"offsetgroup":"1500000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic ZX","Honda Civic VX BSIV"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1445000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1445000.0","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"1445000.0","nbinsx":10,"offsetgroup":"1445000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX CVT"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %%
#top10 Cheapest cars with fuel typ as petrol and suspension type as Automatic
df_petrol_aut=df[(df['Fuel Type']==' Petrol ') & (df['Suspension']==' Automatic')]
df_petrol_aut_top10_ch=df_petrol_aut.sort_values('Price',ascending=False).tail(10)
df_petrol_aut_top10_ch
# Out:
#      Year  kms Driven Fuel Type  Suspension     Price                Car Model
# 851  2009       67300   Petrol    Automatic  235000.0      Honda City 1.5 S AT
# 791  2010       90000   Petrol    Automatic  230000.0          Honda City V AT
# 770  2007      130000   Petrol    Automatic  200000.0  Honda Accord VTi-L (AT)
# 577  2008      100000   Petrol    Automatic  200000.0     Honda Civic 1.8 S AT
# 482  2009       92034   Petrol    Automatic  200000.0     Honda Civic 1.8 V AT
# 102  2008      120054   Petrol    Automatic  196000.0     Honda Civic 1.8 V AT
# 532  2009       72000   Petrol    Automatic  195000.0     Honda Civic 1.8 V AT
# 360  2008       71000   Petrol    Automatic  195000.0     Honda Civic 1.8 V AT
# 506  2009      102816   Petrol    Automatic  180000.0      Honda City 1.5 S AT
# 383  2009      107124   Petrol    Automatic  175000.0      Honda City 1.5 V AT

# %%
#visualization
fig=px.histogram(df_petrol_aut_top10_ch,x='Car Model',nbins=10,color='Price',text_auto=True)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="3025a8a0-5612-4be4-adfa-acb2e56e61ee" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3025a8a0-5612-4be4-adfa-acb2e56e61ee")) {                    Plotly.newPlot(                        "3025a8a0-5612-4be4-adfa-acb2e56e61ee",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=235000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"235000.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"235000.0","nbinsx":10,"offsetgroup":"235000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City 1.5 S AT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=229999.99999999997<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"229999.99999999997","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"229999.99999999997","nbinsx":10,"offsetgroup":"229999.99999999997","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City V AT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=200000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"200000.0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"200000.0","nbinsx":10,"offsetgroup":"200000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Accord VTi-L (AT)","Honda Civic 1.8 S AT","Honda Civic 1.8 V AT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=196000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"196000.0","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"196000.0","nbinsx":10,"offsetgroup":"196000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic 1.8 V AT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=195000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"195000.0","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"195000.0","nbinsx":10,"offsetgroup":"195000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic 1.8 V AT","Honda Civic 1.8 V AT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=180000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"180000.0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"180000.0","nbinsx":10,"offsetgroup":"180000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City 1.5 S AT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=175000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"175000.0","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"175000.0","nbinsx":10,"offsetgroup":"175000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City 1.5 V AT"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0. ...

# %%
#top10 costliest cars with fuel type as petrol and suspension type as Manual
df_petrol_man=df[(df['Fuel Type']==' Petrol ') & (df['Suspension']==' Manual')]
df_petrol_man_top10=df_petrol_man.sort_values('Price',ascending=False).head(10)
df_petrol_man_top10
# Out:
#      Year  kms Driven Fuel Type Suspension      Price             Car Model
# 222  2022        1661   Petrol      Manual  1600000.0      Honda City VX MT
# 397  2022        5045   Petrol      Manual  1450000.0      Honda City ZX MT
# 95   2022        4696   Petrol      Manual  1448000.0      Honda City ZX MT
# 854  2022        8700   Petrol      Manual  1400000.0      Honda City ZX MT
# 451  2022       16000   Petrol      Manual  1400000.0  Honda City i-VTEC ZX
# 695  2022       15500   Petrol      Manual  1380000.0      Honda City ZX MT
# 736  2020       12487   Petrol      Manual  1345000.0   Honda City i-VTEC S
# 16   2021        1425   Petrol      Manual  1325000.0      Honda City VX MT
# 48   2020       20942   Petrol      Manual  1296000.0      Honda City ZX MT
# 797  2020       35000   Petrol      Manual  1295000.0      Honda City ZX MT

# %%
fig=px.histogram(df_petrol_man_top10,x='Car Model',nbins=10,color='Price',text_auto=True)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="bccccf6c-c68b-4fba-b1e0-56cc82b95d0c" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bccccf6c-c68b-4fba-b1e0-56cc82b95d0c")) {                    Plotly.newPlot(                        "bccccf6c-c68b-4fba-b1e0-56cc82b95d0c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1600000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1600000.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1600000.0","nbinsx":10,"offsetgroup":"1600000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City VX MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1450000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1450000.0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1450000.0","nbinsx":10,"offsetgroup":"1450000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1448000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1448000.0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1448000.0","nbinsx":10,"offsetgroup":"1448000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1400000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1400000.0","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1400000.0","nbinsx":10,"offsetgroup":"1400000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX MT","Honda City i-VTEC ZX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1380000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1380000.0","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1380000.0","nbinsx":10,"offsetgroup":"1380000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1345000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1345000.0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"1345000.0","nbinsx":10,"offsetgroup":"1345000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City i-VTEC S"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1325000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1325000.0","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"1325000.0","nbinsx":10,"offsetgroup":"1325000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City VX MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1296000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1296000.0","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"1296000.0","nbinsx":10,"offsetgroup":"1296000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1295000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1295000.0","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"1295000.0","nbinsx":10,"offsetgroup":"1295000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City ZX MT"],"xa ...

# %%
#top10 cheapest cars with fuel type as petrol and suspension type as Manual
df_petrol_man=df[(df['Fuel Type']==' Petrol ') & (df['Suspension']==' Manual')]
df_petrol_man_top10_ch=df_petrol_man.sort_values('Price',ascending=False).tail(10)
df_petrol_man_top10_ch
# Out:
#      Year  kms Driven Fuel Type Suspension     Price             Car Model
# 764  2009       87163   Petrol      Manual  100000.0   Honda City 1.5 S MT
# 652  2008      114502   Petrol      Manual  100000.0  Honda Civic 1.8 V MT
# 572  2008      223000   Petrol      Manual  100000.0        Honda City GXi
# 637  2009       78216   Petrol      Manual  100000.0      Honda Jazz Basic
# 939  2008       92000   Petrol      Manual   95000.0        Honda City GXi
# 973  2006      186719   Petrol      Manual   90000.0        Honda City GXi
# 802  2007      120000   Petrol      Manual   85000.0       Honda City VTEC
# 594  2008       39460   Petrol      Manual   80000.0  Honda Civic 1.8 S MT
# 828  2005      110000   Petrol      Manual   60000.0    Honda City 1.5 GXI
# 588  2003      149714   Petrol      Manual   45000.0    Honda City 1.5 GXI

# %%
fig=px.histogram(df_petrol_man_top10_ch,x='Car Model',nbins=10,color='Price',text_auto=True)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="814e511b-136b-440b-a1ee-06ba8a022627" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("814e511b-136b-440b-a1ee-06ba8a022627")) {                    Plotly.newPlot(                        "814e511b-136b-440b-a1ee-06ba8a022627",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=100000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"100000.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"100000.0","nbinsx":10,"offsetgroup":"100000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City 1.5 S MT","Honda Civic 1.8 V MT","Honda City GXi","Honda Jazz Basic"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=95000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"95000.0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"95000.0","nbinsx":10,"offsetgroup":"95000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City GXi"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=90000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"90000.0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"90000.0","nbinsx":10,"offsetgroup":"90000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City GXi"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=85000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"85000.0","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"85000.0","nbinsx":10,"offsetgroup":"85000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City VTEC"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=80000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"80000.0","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"80000.0","nbinsx":10,"offsetgroup":"80000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic 1.8 S MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=60000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"60000.0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"60000.0","nbinsx":10,"offsetgroup":"60000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City 1.5 GXI"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=45000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"45000.0","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"45000.0","nbinsx":10,"offsetgroup":"45000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City 1.5 GXI"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[ ...

# %%
#To see the df which has fuel type as Diesel and Suspension type as Automatic
#This df has totally 5 cars
df_diesel_aut=df[(df['Fuel Type']==' Diesel ') & (df['Suspension']==' Automatic')]
df_diesel_aut
# Out:
#      Year  kms Driven Fuel Type  Suspension      Price  \
# 38   2019       68816   Diesel    Automatic   795000.0
# 390  2019       50175   Diesel    Automatic  2650000.0
# 505  2018       50000   Diesel    Automatic   730000.0
# 761  2018       53955   Diesel    Automatic   675000.0
# 917  2021       30000   Diesel    Automatic  1150000.0
#
#                      Car Model
# 38   Honda Amaze V CVT Diesel
# 390      Honda CR-V Diesel 2WD
# 505  Honda Amaze S CVT Diesel
# 761  Honda Amaze V CVT Diesel
# 917  Honda Amaze VX CVT Diesel

# %%
#top10 costliest cars with fuel typ as Diesel and suspension type as Manual
df_diesel_aut=df[(df['Fuel Type']==' Diesel ') & (df['Suspension']==' Manual')]
df_diesel_man_top10=df_diesel_aut.sort_values('Price',ascending=False).head(10)
df_diesel_man_top10
# Out:
#      Year  kms Driven Fuel Type Suspension      Price               Car Model
# 858  2019       79000   Diesel      Manual  1720000.0   Honda Civic VX Diesel
# 714  2019       23561   Diesel      Manual  1100000.0  Honda BR-V i-DTEC V MT
# 840  2019       40000   Diesel      Manual  1090000.0    Honda City i-DTEC VX
# 929  2019       80000   Diesel      Manual  1010000.0    Honda WR-V i-DTEC VX
# 952  2021       70000   Diesel      Manual  1000000.0    Honda WR-V VX Diesel
# 325  2019       54000   Diesel      Manual   990000.0    Honda City i-DTEC VX
# 738  2017       31000   Diesel      Manual   975000.0    Honda City i-DTEC ZX
# 228  2020       33174   Diesel      Manual   920000.0    Honda WR-V i-DTEC VX
# 941  2019      110000   Diesel      Manual   915000.0    Honda WR-V i-DTEC VX
# 966  2018       60000   Diesel      Manual   900000.0     Honda City i-DTEC V

# %%
#Graphical representation
fig=px.histogram(df_diesel_man_top10,x='Car Model',nbins=10,color='Price',text_auto=True)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="55d5f488-b9b4-4d1d-8557-aa9f32f10d45" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55d5f488-b9b4-4d1d-8557-aa9f32f10d45")) {                    Plotly.newPlot(                        "55d5f488-b9b4-4d1d-8557-aa9f32f10d45",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1720000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1720000.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1720000.0","nbinsx":10,"offsetgroup":"1720000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Civic VX Diesel"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1100000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1100000.0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1100000.0","nbinsx":10,"offsetgroup":"1100000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda BR-V i-DTEC V MT"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1090000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1090000.0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1090000.0","nbinsx":10,"offsetgroup":"1090000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City i-DTEC VX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1010000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1010000.0","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1010000.0","nbinsx":10,"offsetgroup":"1010000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda WR-V i-DTEC VX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=1000000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1000000.0","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1000000.0","nbinsx":10,"offsetgroup":"1000000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda WR-V VX Diesel"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=990000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"990000.0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"990000.0","nbinsx":10,"offsetgroup":"990000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City i-DTEC VX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=975000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"975000.0","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"975000.0","nbinsx":10,"offsetgroup":"975000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda City i-DTEC ZX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=919999.9999999999<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"919999.9999999999","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"919999.9999999999","nbinsx":10,"offsetgroup":"919999.9999999999","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda WR-V i-DTEC VX"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=915000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"915000.0","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"915000.0","nbinsx":10,"offsetgroup":"915000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}" ...

# %%
#top10 cheapest cars with fuel typ as Diesel and suspension type as Manual
df_diesel_man_top10_ch=df_diesel_aut.sort_values('Price',ascending=False).tail(10)
df_diesel_man_top10_ch
# Out:
#      Year  kms Driven Fuel Type Suspension     Price               Car Model
# 492  2013       88000   Diesel      Manual  250000.0   Honda Amaze S i-Dtech
# 585  2014      125690   Diesel      Manual  245000.0   Honda Amaze S i-Dtech
# 806  2014       91332   Diesel      Manual  230000.0   Honda Amaze S i-Dtech
# 921  2013      110000   Diesel      Manual  230000.0  Honda Amaze EX i-Dtech
# 554  2014       66776   Diesel      Manual  230000.0   Honda Amaze S i-Dtech
# 571  2014      205546   Diesel      Manual  225000.0  Honda Mobilio V i-DTEC
# 576  2015       95338   Diesel      Manual  225000.0   Honda Amaze S i-Dtech
# 380  2013      114565   Diesel      Manual  212000.0   Honda Amaze S i-Dtech
# 634  2014       79303   Diesel      Manual  200000.0  Honda Amaze EX i-Dtech
# 229  2013      110000   Diesel      Manual  200000.0   Honda Amaze E i-Dtech

# %%
#Graphical representation
fig=px.histogram(df_diesel_man_top10_ch,x='Car Model',nbins=10,color='Price',text_auto=True)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="51466f3a-859a-41fd-9fca-405177de556e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51466f3a-859a-41fd-9fca-405177de556e")) {                    Plotly.newPlot(                        "51466f3a-859a-41fd-9fca-405177de556e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=250000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"250000.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"250000.0","nbinsx":10,"offsetgroup":"250000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Amaze S i-Dtech"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=245000.00000000003<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"245000.00000000003","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"245000.00000000003","nbinsx":10,"offsetgroup":"245000.00000000003","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Amaze S i-Dtech"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=229999.99999999997<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"229999.99999999997","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"229999.99999999997","nbinsx":10,"offsetgroup":"229999.99999999997","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Amaze S i-Dtech","Honda Amaze EX i-Dtech","Honda Amaze S i-Dtech"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=225000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"225000.0","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"225000.0","nbinsx":10,"offsetgroup":"225000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Mobilio V i-DTEC","Honda Amaze S i-Dtech"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=212000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"212000.0","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"212000.0","nbinsx":10,"offsetgroup":"212000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Amaze S i-Dtech"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=200000.0<br>Car Model=%{x}<br>count=%{y}<extra></extra>","legendgroup":"200000.0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"200000.0","nbinsx":10,"offsetgroup":"200000.0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Honda Amaze EX i-Dtech","Honda Amaze E i-Dtech"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"co ...

# %%
#Finding correlation among the numerical columns
corr=df.corr()
corr
# Out:
#                 Year  kms Driven     Price
# Year        1.000000   -0.366504  0.766076
# kms Driven -0.366504    1.000000 -0.309837
# Price       0.766076   -0.309837  1.000000

# %%
#creating heatmap to have clear identification of the relationship
fig=plt.figure(figsize=(8,6),dpi=100)
sns.heatmap(data=corr,annot=True, cmap='rocket')
# Out:
# <AxesSubplot:>
